# %% [markdown]
# # Trap Intensity Sensitivity
#
# Finds how the trap site center intensity depends on various parameters such as the spot transmission, relative phase between spots and background, and iris radius.
#
# Another notebook in the series of analysis of Mark's trap array design.

# %%
## general imports
import numpy as np
from numpy import *
from numpy.fft import fft,fft2,fftshift,ifftshift

from scipy.special import j0, j1
from matplotlib import colors
import matplotlib.pyplot as plt
from time import time
from random import random as rand

## local imports
import os,sys
sys.path.append(os.path.join("..","."))
from field_funcs import * # my helper functions
from physconsts import *
from simfuncs import *

## make the display wide
from IPython.core.display import HTML, display, Image
display(HTML("<style>.container{width:100% !important;}</style>"))

# image path 
imagedir = os.path.join('..','images')
print("images saved in", imagedir)

# for matplotlib labels
fontsize=14

def savefigure(fname):
    filepath = os.path.join(imagedir,fname)
    plt.savefig(filepath, bbox_inches='tight')
    print("saved file to",filepath)
# Out:
# <style>.container{width:100% !important;}</style>
# images saved in ..\images

# %% [markdown]
# ## Spot reflection
#
# No phase difference between disk and background, but check the dependence of the trap depth on spot reflection.

# %%
## physics and lens params
# lengths in m

lmbda = 8.05e-7
nu0 = c/lmbda
k = 2*pi/lmbda

f1 = 0.5 # lens focal length
f2 = 0.005
A0 = 1 # input field amplitude

# input mask params
a = 1e-4 # spot radius
dx = 4.3*a # grid periodicity
dy = dx
b = f1*3.8317/(a*k) # fourier plane filter radius
xnum1 = ynum1 = 10 # number of grid points in each dimension

## output field Talbot lengths
Lx2 = f2*dx/f1 # output array periodicity
Ly2 = f2*dy/f1
zTalbotx = 2*Lx2**2/lmbda 
zTalboty = 2*Ly2**2/lmbda 

## print out parameters
print("length units are m:")
print(f'b={b:0.6f}, a={a}, dx={dx}, dy={dy}, xnum={xnum1}, ynum={ynum1}')
print(f'zTalbotx={zTalbotx:0.6f}, zTalboty={zTalboty:0.6f}')
# Out:
# length units are m:
# b=0.002455, a=0.0001, dx=0.00043, dy=0.00043, xnum=10, ynum=10
# zTalbotx=0.000046, zTalboty=0.000046

# %%
## create a mask that induces a phase difference between spots and background

pts = 1000
phi_std=None # [rad]
pos_std=None
T_aper = 0.082
r_aper = sqrt(1-T) # aperture reflectivity
t_plate = 1 # plate transmissivity
# the mask with desired transmission properties
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T), plate=t_plate)

# spot phase mask.
spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
phi = 0
spot_phases *= exp(-1j*phi)

# mask with 1's on background, 0's on spots.
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

phase_mask = spot_phases + complement

# finally, apply the phases to the transmission mask
field0 = mask*phase_mask

fig,ax1 = plt.subplots()
ax1.plot(range(pts), abs(field0[800,:]),color='blue')
ax1.set_ylabel("transmission",color='blue')
ax1.set_ylim((0,1.1))

ax2 = ax1.twinx()
ax2.plot(range(pts), angle(field0[800,:]),color='red')
ax2.set_ylabel("phase [rad]",color='red')
ax2.set_ylim((-pi,pi))

# plt.imshow(real(conjugate(field0)*field0))
# Out:
# (-3.141592653589793, 3.141592653589793)

# %%
field0[800,:].shape
# Out:
# (1000,)

# %%
plt.close()
fig,ax = plt.subplots(dpi=100)
plt.imshow(abs(field0))
ax.axvline(453)

# %%
linspace(0.05,0.12,7)
# Out:
# array([0.05      , 0.06166667, 0.07333333, 0.085     , 0.09666667,
#        0.10833333, 0.12      ])

# %%
sqrt(T),1-sqrt(1-T)
# Out:
# (0.34641016151377546, 0.061916848035314054)

# %%
# input mask
pts = 1000
phi_std=None # [rad]
pos_std=None

phi = 0
T_aper = 0.082
r_aper = sqrt(1-T) # aperture reflectivity
t_plate = 1 # plate transmissivity
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

# range of spot phases wrt to background
numsteps = 7
T_steps = linspace(0.05,0.12,numsteps) 
I2max = 1

z2 = f2 # output plane

xslice = 453 # x coordinate of the slice
slices_soln = empty((pts,numsteps),dtype=float) 

for i,T in enumerate(T_steps):

    # calculate the input field
    print(f'T={T}')
    mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T), plate=t_plate)
    
    # add phases to input field 
#     spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
#     spot_phases *= exp(-1j*phi*pi/180)
#     phase_mask = spot_phases + complement

    # finally, apply the phases to the transmission mask
#     field0 = mask*phase_mask
    field0 = mask

    # FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
    padding= int(pts/2) 
    rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
    field1,x1pts = lens_xform(f1,field0,b,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                              logging=False)

    # OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
    rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
    field2,x2pts = lens_xform(z2,field1,b,f2,k,x1pts,rr1,padding,masked=True,
                              logging=False)
    
#     if phi == 0:
#         I2max = max(abs(field2[:,xslice])**2)
#         print("obtained normalization factor")
    
    slices_soln[:,i] = abs(field2[:,xslice])**2
    print(f"step {i} completed")
    
I2max = max(abs(field2[:,xslice])**2)
for i in range(numsteps):
    slices_soln[:,i] /= I2max
# Out:
# T=0.05
# step 0 completed
# T=0.06166666666666667
# step 1 completed
# T=0.07333333333333333
# step 2 completed
# T=0.08499999999999999
# step 3 completed
# T=0.09666666666666666
# step 4 completed
# T=0.10833333333333334
# step 5 completed
# T=0.12
# step 6 completed

# %%
[T_steps[i] for i in [1,3,5,7,10]]
# Out:
# [0.08272727272727273,
#  0.1741818181818182,
#  0.2656363636363636,
#  0.35709090909090907,
#  0.49427272727272725]

# %%
savefig=False
fig,ax = plt.subplots()
for i in range(numsteps):
    ax.plot(range(pts),slices_soln[:,i],label=f'T={T_steps[i]:0.2f}')
ax.set_title("Trap Intensity Dependence on Transmittance",fontsize=fontsize)
ax.set_xlabel("x [Arb.]",fontsize=fontsize)
ax.set_ylabel("Intensity",fontsize=fontsize)
ax.set_ylim((0,0.025))
ax.set_xlim((440,470))
ax.legend()
if savefig:
    fname = f"plot_trap_profile_spot_T_dependence_{int(100*t_plate)}_T_steps_{int(100*T_steps[0])}_{int(100*T_steps[-1])}_{numsteps}pts.png"
    savefigure(fname)

# %% [markdown]
# ## Spot phases

# %%
## physics and lens params
# lengths in m

lmbda = 8.05e-7
nu0 = c/lmbda
k = 2*pi/lmbda

f1 = 0.5 # lens focal length
f2 = 0.005
A0 = 1 # input field amplitude

# input mask params
a = 1e-4 # spot radius
dx = 4.3*a # grid periodicity
dy = dx
b = f1*3.8317/(a*k) # fourier plane filter radius
xnum1 = ynum1 = 10 # number of grid points in each dimension

## output field Talbot lengths
Lx2 = f2*dx/f1 # output array periodicity
Ly2 = f2*dy/f1
zTalbotx = 2*Lx2**2/lmbda 
zTalboty = 2*Ly2**2/lmbda 

## print out parameters
print("length units are m:")
print(f'b={b:0.6f}, a={a}, dx={dx}, dy={dy}, xnum={xnum1}, ynum={ynum1}')
print(f'zTalbotx={zTalbotx:0.6f}, zTalboty={zTalboty:0.6f}')
# Out:
# length units are m:
# b=0.002455, a=0.0001, dx=0.00043, dy=0.00043, xnum=10, ynum=10
# zTalbotx=0.000046, zTalboty=0.000046

# %%
## create a mask that induces a phase difference between spots and background

pts = 1000
phi_std=None # [rad]
pos_std=None
T_aper = 0.0827
r_aper = sqrt(1-T_aper) # aperture reflectivity
t_plate = 1 # plate transmissivity
# the mask with desired transmission properties
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)

# spot phase mask.
spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
phi = 0
spot_phases *= exp(-1j*phi)

# mask with 1's on background, 0's on spots.
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

phase_mask = spot_phases + complement

# finally, apply the phases to the transmission mask
field0 = mask*phase_mask

fig,ax1 = plt.subplots()
ax1.plot(range(pts), abs(field0[800,:]),color='blue')
ax1.set_ylabel("transmission",color='blue')
ax1.set_ylim((0,1.1))

ax2 = ax1.twinx()
ax2.plot(range(pts), angle(field0[800,:]),color='red')
ax2.set_ylabel("phase [rad]",color='red')
ax2.set_ylim((-pi,pi))

# plt.imshow(real(conjugate(field0)*field0))
# Out:
# (-3.141592653589793, 3.141592653589793)

# %%
field0[800,:].shape
# Out:
# (1000,)

# %%
plt.close()
fig,ax = plt.subplots(dpi=100)
plt.imshow(abs(field0))
ax.axvline(453)

# %%
linspace(0.05,0.12,7)
# Out:
# array([0.05      , 0.06166667, 0.07333333, 0.085     , 0.09666667,
#        0.10833333, 0.12      ])

# %%
sqrt(T),1-sqrt(1-T)
# Out:
# (0.34641016151377546, 0.061916848035314054)

# %%
# input mask
pts = 1000
phi_std=None # [rad]
pos_std=None

phi = 0
T_aper = 0.0827
r_aper = sqrt(1-T) # aperture reflectivity
t_plate = 1 # plate transmissivity
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

# range of spot phases wrt to background
numsteps = 5
phi_steps = linspace(0,20,numsteps) 
I2max = 1

z2 = f2 # output plane

xslice = 453 # x coordinate of the slice
slices_soln = empty((pts,numsteps),dtype=float) 

for i,phi in enumerate(phi_steps):

    # calculate the input field
    print(f'phi={phi}')
    mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
    
#     add phases to input field 
    spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
    spot_phases *= exp(-1j*phi*pi/180)
    phase_mask = spot_phases + complement

#     finally, apply the phases to the transmission mask
    field0 = mask*phase_mask
#     field0 = mask

    # FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
    padding= int(pts/2) 
    rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
    field1,x1pts = lens_xform(f1,field0,b,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                              logging=False)

    # OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
    rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
    field2,x2pts = lens_xform(z2,field1,b,f2,k,x1pts,rr1,padding,masked=True,
                              logging=False)
    
    if phi == 0:
        I2max = max(abs(field2[:,xslice])**2)
        print("obtained normalization factor")
    
    slices_soln[:,i] = abs(field2[:,xslice])**2
    print(f"step {i} completed")
    
# I2max = max(abs(field2[:,xslice])**2)
for i in range(numsteps):
    slices_soln[:,i] /= I2max
# Out:
# phi=0.0
# obtained normalization factor
# step 0 completed
# phi=5.0
# step 1 completed
# phi=10.0
# step 2 completed
# phi=15.0
# step 3 completed
# phi=20.0
# step 4 completed

# %%
savefig=True
fig,ax = plt.subplots()
for i in range(numsteps):
    ax.plot(range(pts),slices_soln[:,i],label=f'$\phi$={phi_steps[i]:0.2f}')
ax.set_title("Trap Intensity Dependence on \nRelative Spot-Background Phase",fontsize=fontsize)
ax.set_xlabel("x [Arb.]",fontsize=fontsize)
ax.set_ylabel("Intensity",fontsize=fontsize)
ax.set_ylim((0,0.025))
ax.set_xlim((440,470))
ax.legend()
if savefig:
    fname = f"plot_trap_profile_spot_t_plate_{int(100*t_plate)}_T_aper_{int(100*T_aper)}_phi_steps_{int(phi_steps[0]/pi)}_{int(phi_steps[-1])}_{numsteps}pts.png"
    savefigure(fname)
# Out:
# saved file to ..\images\plot_trap_profile_spot_t_plate_100_T_aper_8_phi_steps_0_20_5pts.png

# %%
f"plot_trap_min_vs_spot_phase_tplate{int(100*t_plate)}_rspot{int(100*(1-r_aper))}_{numsteps}pts.png"
# Out:
# 'plot_trap_min_vs_spot_phase_tplate80_rspot25_101pts.png'

# %%
savefig=False
fig,ax = plt.subplots()
ax.set_title(r"Trap intensity vs spot phases" + "\n (normalized to intensity for $\phi=0^\circ$)" )
ax.set_xlabel("Spot phase w.r.t. plate [deg.]",fontsize=fontsize)
ax.set_ylabel(r"Trap intensity minimum",fontsize=fontsize)
ax.plot(phase_steps, [slices_soln[455,i] for i in range(numsteps)],color='crimson')
if savefig:
    fname = f"plot_trap_min_vs_spot_phase_tplate{int(100*t_plate)}_rspot{int(100*(1-r_aper))}_pi{abs(int(phase_steps[0]))}_pf{abs(int(phase_steps[-1]))}_{numsteps}pts.png"
    savefigure(fname)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11524/529467251.py in <module>
#       4 ax.set_xlabel("Spot phase w.r.t. plate [deg.]",fontsize=fontsize)
#       5 ax.set_ylabel(r"Trap intensity minimum",fontsize=fontsize)
# ----> 6 ax.plot(phase_steps, [slices_soln[455,i] for i in range(numsteps)],color='crimson')
#       7 if savefig:
#       8     fname = f"plot_trap_min_vs_spot_phase_tplate{int(100*t_plate)}_rspot{int(100*(1-r_aper))}_pi{abs(int(phase_steps[0]))}_pf{abs(int(phase_steps[-1]))}_{numsteps}pts.png"
#
# ~\.virtualenvs\fourier-optics-rBKOIr-o\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\.virtualenvs\fourier-optics-rBKOIr-o\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\.virtualenvs\fourier-optics-rBKOIr-o\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     499
#     500         if x.shape[0] != y.shape[0]:
# --> 501             raise ValueError(f"x and y must have same first dimension, but "
#     502                              f"have shapes {x.shape} and {y.shape}")
#     503         if x.ndim > 2 or y.ndim > 2:
#
# ValueError: x and y must have same first dimension, but have shapes (3,) and (5,)

# %% [markdown]
# ## Iris radius and spot phase

# %%
## physics and lens params
# lengths in m

lmbda = 8.08e-7
nu0 = c/lmbda
k = 2*pi/lmbda

f1 = 0.5 # lens focal length
f2 = 0.005
A0 = 1 # input field amplitude

# input mask params
a = 1e-4 # spot radius
dx = 4.3*a # grid periodicity
dy = dx
b = f1*3.8317/(a*k) # fourier plane filter radius
xnum1 = ynum1 = 10 # number of grid points in each dimension

## output field Talbot lengths
Lx2 = f2*dx/f1 # output array periodicity
Ly2 = f2*dy/f1
zTalbotx = 2*Lx2**2/lmbda
zTalboty = 2*Ly2**2/lmbda

## print out parameters
print("length units are m:")
print(f'b={b:0.6f}, a={a}, dx={dx}, dy={dy}, xnum={xnum1}, ynum={ynum1}')
print(f'zTalbotx={zTalbotx:0.6f}, zTalboty={zTalboty:0.6f}')
# Out:
# length units are m:
# b=0.002464, a=0.0001, dx=0.00043, dy=0.00043, xnum=10, ynum=10
# zTalbotx=0.000046, zTalboty=0.000046

# %%
## create a mask that induces a phase difference between spots and background

pts = 1000
phi_std=None # [rad]
pos_std=None
T_aper = 0.0827
r_aper = sqrt(1-T_aper) # aperture reflectivity
t_plate = 1 # plate transmissivity
# the mask with desired transmission properties
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)

# spot phase mask.
spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
phi = 0
spot_phases *= exp(-1j*phi)

# mask with 1's on background, 0's on spots.
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

phase_mask = spot_phases + complement

# finally, apply the phases to the transmission mask
field0 = mask*phase_mask

fig,ax1 = plt.subplots()
ax1.plot(range(pts), abs(field0[800,:]),color='blue')
ax1.set_ylabel("transmission",color='blue')
ax1.set_ylim((0,1.1))

ax2 = ax1.twinx()
ax2.plot(range(pts), angle(field0[800,:]),color='red')
ax2.set_ylabel("phase [rad]",color='red')
ax2.set_ylim((-pi,pi))
# Out:
# (-3.141592653589793, 3.141592653589793)

# %%
plt.imshow(real(conjugate(field0)*field0))
plt.axhline(xslice)

# %%
# input mask
pts = 1000
phi_std=None # [rad]
pos_std=None

phi = 0
T_aper = 0.49 # a far from optimal reflectivity value
r_aper = sqrt(1-T) # aperture reflectivity
t_plate = 1 # plate transmissivity
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

# range of spot phases wrt to background
numsteps = 21
b_steps = linspace(0.5*b,1.5*b,numsteps) 
I2max = 1

z2 = f2 # output plane

xslice = 453 # x coordinate of the slice
slices_soln = empty((pts,numsteps),dtype=float) 

for i,bs in enumerate(b_steps):

    # calculate the input field
    print(f'b={bs*1e3}mm')
    mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
    
#     add phases to input field 
#     spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
#     spot_phases *= exp(-1j*phi*pi/180)
#     phase_mask = spot_phases + complement

#     finally, apply the phases to the transmission mask
#     field0 = mask*phase_mask
    field0 = mask

    # FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
    padding= int(pts/2) 
    rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
    field1,x1pts = lens_xform(f1,field0,bs,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                              logging=False)

    # OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
    rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
    field2,x2pts = lens_xform(z2,field1,bs,f2,k,x1pts,rr1,padding,masked=True,
                              logging=False)
    
    if bs == b:
        I2max = max(abs(field2[:,xslice])**2)
        print("obtained normalization factor")
    
    slices_soln[:,i] = abs(field2[:,xslice])**2
    print(f"step {i} completed")
    
I2max = max(abs(field2[:,xslice])**2)
for i in range(numsteps):
    slices_soln[:,i] /= I2max
# Out:
# b=1.2272909158334961mm
# step 0 completed
# b=1.3500200074168458mm
# step 1 completed
# b=1.4727490990001955mm
# step 2 completed
# b=1.595478190583545mm
# step 3 completed
# b=1.7182072821668946mm
# step 4 completed
# b=1.8409363737502442mm
# step 5 completed
# b=1.9636654653335937mm
# step 6 completed
# b=2.086394556916943mm
# step 7 completed
# b=2.209123648500293mm
# step 8 completed
# b=2.3318527400836424mm
# step 9 completed
# b=2.4545818316669923mm
# obtained normalization factor
# step 10 completed
# b=2.5773109232503417mm
# step 11 completed
# b=2.7000400148336916mm
# step 12 completed
# b=2.822769106417041mm
# step 13 completed
# b=2.9454981980003905mm
# step 14 completed
# b=3.06822728958374mm
# step 15 completed
# b=3.19095638116709mm
# step 16 completed
# b=3.3136854727504392mm
# step 17 completed
# b=3.436414564333789mm
# step 18 completed
# b=3.5591436559171385mm
# step 19 completed
# b=3.6818727475004884mm
# step 20 completed

# %%
[]

# %%
savefig=False
fig,ax = plt.subplots(dpi=100)
for i in [8]:
    ax.plot(range(pts),slices_soln[:,i],label=f'b={b_steps[i]*1e3:0.2f}')
ax.set_title("Trap Intensity Dependence on \nIris Radius. T_aper = 0.49",fontsize=fontsize)
ax.set_xlabel("x [Arb.]",fontsize=fontsize)
ax.set_ylabel("Intensity",fontsize=fontsize)
# ax.set_ylim((0,0.025))
ax.set_xlim((440,470))
ax.legend()
if savefig:
    fname = f"plot_trap_profile_spot_t_plate_{int(100*t_plate)}_T_aper_{int(100*T_aper)}_b_steps_{int(b_steps[0]*1e6)}_{int(b_steps[-1])}um_{numsteps}pts.png"
    savefigure(fname)

# %%
# input mask
pts = 1000
phi_std=None # [rad]
pos_std=None

phi = 0
bs = 0.00221
ta = 0.49
tb = 1 # background transmission amp.
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=ta, plate=tb)
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

# range of spot phases wrt to background
numsteps = 11
phi_steps = linspace(0,45,numsteps) 
I2max = 1

z2 = f2 # output plane

xslice = 453 # x coordinate of the slice
slices_soln = empty((pts,numsteps),dtype=float)

for i,phi in enumerate(phi_steps):

    # calculate the input field
    print(f'phi={phi}')
    mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
    
#     add phases to input field 
    spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
    spot_phases *= exp(-1j*phi*pi/180)
    phase_mask = spot_phases + complement

#     finally, apply the phases to the transmission mask
    field0 = mask*phase_mask
#     field0 = mask

    # FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
    padding= int(pts/2) 
    rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
    field1,x1pts = lens_xform(f1,field0,bs,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                              logging=False)

    # OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
    rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
    field2,x2pts = lens_xform(z2,field1,bs,f2,k,x1pts,rr1,padding,masked=True,
                              logging=False)
    
    if phi == 0:
        I2max = max(abs(field2[:,xslice])**2)
        print("obtained normalization factor")
    
    slices_soln[:,i] = abs(field2[:,xslice])**2
    print(f"step {i} completed")
    
# I2max = max(abs(field2[:,xslice])**2)
for i in range(numsteps):
    slices_soln[:,i] /= I2max
# Out:
# phi=0.0
# obtained normalization factor
# step 0 completed
# phi=4.5
# step 1 completed
# phi=9.0
# step 2 completed
# phi=13.5
# step 3 completed
# phi=18.0
# step 4 completed
# phi=22.5
# step 5 completed
# phi=27.0
# step 6 completed
# phi=31.5
# step 7 completed
# phi=36.0
# step 8 completed
# phi=40.5
# step 9 completed
# phi=45.0
# step 10 completed

# %%
savefig=False
fig,ax = plt.subplots()
for i in range(numsteps):
    ax.plot(range(pts),slices_soln[:,i],label=f'$\phi$={phi_steps[i]:0.2f}')
ax.set_title("Trap Intensity Dependence on \nRelative Spot-Background Phase",fontsize=fontsize)
ax.set_xlabel("x [Arb.]",fontsize=fontsize)
ax.set_ylabel("Intensity",fontsize=fontsize)
# ax.set_ylim((0,0.025))
ax.set_xlim((440,470))
ax.legend()
if savefig:
    fname = f"plot_trap_profile_spot_b_{int(1e6*bs)}us_t_plate_{int(100*t_plate)}_T_aper_{int(100*T_aper)}_phi_steps_{int(phi_steps[0]/pi)}_{int(phi_steps[-1])}_{numsteps}pts.png"
    savefigure(fname)

# %%
# sanity check before simultaneously checking phase and radius b

# input mask
pts = 1000
phi_std=None # [rad]
pos_std=None

phi = 0
bs = f1*3.8317/(a*k)
ta = 0.287119
tb = 1 # plate transmissivity
z2 = f2
xslice = 453
yslice = 455
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=ta, plate=tb)
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)

# compute the correct by which to normalize
field0 = mask
# FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
padding= int(pts/2) 
rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
field1,x1pts = lens_xform(f1,field0,bs,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                          logging=False)
# OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
field2,x2pts = lens_xform(z2,field1,bs,f2,k,x1pts,rr1,padding,masked=True,
                          logging=False)
I2max = max(abs(field2[:,xslice])**2) # normalize everything else to this, including the simulation that follows this

# plt.plot(range(pts),abs(field2[:,xslice])**2/max(abs(field2[:,xslice])**2))
plt.plot(range(pts),abs(field2[yslice,:])**2/max(abs(field2[:,xslice])**2))

plt.ylim((0,1))
# Out:
# (0.0, 1.0)

# %%
# generate trap site center intensity vs iris radius and relative mask phase

numstepsy = 25
numstepsx = 25
ta = 0.287119 #sqrt(0.49)
tb = 1
phi_steps = linspace(0,180,numstepsy) # range of spot phases wrt to background
b_steps = linspace(0.6*1e-3,2.5*1e-3,numstepsx) 

z2 = f2 # output plane

xslice = 453 # x coordinate of the slice
yslice = 455
slices_soln = empty((pts,numstepsx),dtype=float)

ttotal = 0 # time tracker
soln = empty((numstepsy,numstepsx),float)
for i,phi in enumerate(phi_steps):
    for j,bs in enumerate(b_steps):

        t0 = time()
        # calculate the input field
#         print(f'phi={phi}')
        mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=ta, plate=tb)

    #     add phases to input field 
        spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
        spot_phases *= exp(-1j*phi*pi/180)
        phase_mask = spot_phases + complement

    #     finally, apply the phases to the transmission mask
        field0 = mask*phase_mask
    #     field0 = mask

        # FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
        padding= int(pts/2) 
        rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
        field1,x1pts = lens_xform(f1,field0,bs,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                                  logging=False)

        # OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
        rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
        field2,x2pts = lens_xform(z2,field1,bs,f2,k,x1pts,rr1,padding,masked=True,
                                  logging=False)

        soln[i,j] = abs(field2[yslice,xslice])**2
        tf = time()
        ttotal += tf - t0
        print(f"step {j + numstepsx*i} completed in {(tf-t0)/60:.2f}min")
    
# I2max = max(abs(field2[:,xslice])**2)
for i in range(numstepsx):
    slices_soln[:,i] /= I2max
print(f"simulation completed in {ttotal/60:.2f}min")
# Out:
# step 0 completed in 0.02min
# step 1 completed in 0.06min
# step 2 completed in 0.06min
# step 3 completed in 0.06min
# step 4 completed in 0.06min
# step 5 completed in 0.06min
# step 6 completed in 0.06min
# step 7 completed in 0.06min
# step 8 completed in 0.06min
# step 9 completed in 0.06min
# step 10 completed in 0.06min
# step 11 completed in 0.06min
# step 12 completed in 0.06min
# step 13 completed in 0.06min
# step 14 completed in 0.06min
# step 15 completed in 0.06min
# step 16 completed in 0.06min
# step 17 completed in 0.06min
# step 18 completed in 0.06min
# step 19 completed in 0.06min
# step 20 completed in 0.06min
# step 21 completed in 0.06min
# step 22 completed in 0.06min
# step 23 completed in 0.06min
# step 24 completed in 0.06min
# step 25 completed in 0.06min
# step 26 completed in 0.05min
# step 27 completed in 0.06min
# step 28 completed in 0.05min
# step 29 completed in 0.05min
# step 30 completed in 0.06min
# step 31 completed in 0.06min
# step 32 completed in 0.07min
# step 33 completed in 0.06min
# step 34 completed in 0.06min
# step 35 completed in 0.06min
# step 36 completed in 0.06min
# step 37 completed in 0.06min
# step 38 completed in 0.06min
# step 39 completed in 0.06min
# step 40 completed in 0.06min
# step 41 completed in 0.06min
# step 42 completed in 0.06min
# step 43 completed in 0.07min
# step 44 completed in 0.06min
# step 45 completed in 0.06min
# step 46 completed in 0.06min
# step 47 completed in 0.06min
# step 48 completed in 0.06min
# step 49 completed in 0.06min
# step 50 completed in 0.06min
# step 51 completed in 0.06min
# step 52 completed in 0.06min
# step 53 completed in 0.06min
# step 54 completed in 0.06min
# step 55 completed in 0.06min
# step 56 completed in 0.06min
# step 57 completed in 0.06min
# step 58 completed in 0.06min
# step 59 completed in 0.06min
# step 60 completed in 0.06min
# step 61 completed in 0.06min
# step 62 completed in 0.05min
# step 63 completed in 0.06min
# step 64 completed in 0.06min
# step 65 completed in 0.06min
# step 66 completed in 0.06min
# step 67 completed in 0.06min
# step 68 completed in 0.06min
# step 69 completed in 0.06min
# step 70 completed in 0.06min
# step 71 completed in 0.06min
# step 72 completed in 0.06min
# step 73 completed in 0.06min
# step 74 completed in 0.06min
# step 75 completed in 0.06min
# step 76 completed in 0.06min
# step 77 completed in 0.06min
# step 78 completed in 0.06min
# step 79 completed in 0.06min
# step 80 completed in 0.06min
# step 81 completed in 0.06min
# step 82 completed in 0.06min
# step 83 completed in 0.06min
# step 84 completed in 0.06min
# step 85 completed in 0.06min
# step 86 completed in 0.06min
# step 87 completed in 0.05min
# step 88 completed in 0.05min
# step 89 completed in 0.05min
# step 90 completed in 0.06min
# step 91 completed in 0.06min
# step 92 completed in 0.06min
# step 93 completed in 0.06min
# step 94 completed in 0.06min
# step 95 completed in 0.06min
# step 96 completed in 0.06min
# step 97 completed in 0.06min
# step 98 completed in 0.06min
# step 99 completed in 0.06min
# step 100 completed in 0.06min
# step 101 completed in 0.05min
# step 102 completed in 0.05min
# step 103 completed in 0.06min
# step 104 completed in 0.06min
# step 105 completed in 0.06min
# step 106 completed in 0.06min
# step 107 completed in 0.06min
# step 108 completed in 0.06min
# step 109 completed in 0.06min
# step 110 completed in 0.06min
# step 111 completed in 0.06min
# step 112 completed in 0.06min
# step 113 completed in 0.06min
# step 114 completed in 0.06min
# step 115 completed in 0.05min
# step 116 completed in 0.06min
# step 117 completed in 0.06min
# step 118 completed in 0.05min
# step 119 completed in 0.05min
# step 120 completed in 0.06min
# step 121 completed in 0.06min
# step 122 completed in 0.05min
# step 123 completed in 0.06min
# step 124 completed in 0.06min
# step 125 completed in 0.06min
# step 126 completed in 0.06min
# step 127 completed in 0.05min
# step 128 completed in 0.06min
# step 129 completed in 0.06min
# step 130 completed in 0.06min
# step 131 completed in 0.06min
# step 132 completed in 0.06min
# step 133 completed in 0.06min
# step 134 completed in 0.06min
# step 135 completed in 0.06min
# step 136 completed in 0.06min
# step 137 completed in 0.06min
# step 138 completed in 0.06min
# step 139 completed in 0.05min
# step 140 completed in 0.06min
# step 141 completed in 0.06min
# step 142 completed in 0.06min
# step 143 completed in 0.06min
# step 144 completed in 0.06min
# step 145 completed in 0.06min
# step 146 completed in 0.06min
# step 147 completed in 0.06min
# step 148 completed in 0.06min
# step 149 completed in 0.06min
# step 150 completed in 0.06min
# step 151 completed in 0.06min
# step 152 completed in 0.06min
# step 153 completed in 0.06min
# step 154 completed in 0.06min
# step 155 completed in 0.06min
# step 156 completed in 0.05min
# step 157 completed in 0.06min
# step 158 completed in 0.06min
# step 159 completed in 0.05min
# step 160 completed in 0.06min
# step 161 completed in 0.06min
# step 162 completed in 0.06min
# step 163 completed in 0.06min
# step 164 completed in 0.06min
# step 165 completed in 0.06min
# step 166 completed in 0.06min
# step 167 completed in 0.06min
# step 168 completed in 0.06min
# step 169 completed in 0.06min
# step 170 completed in 0.06min
# step 171 completed in 0.06min
# step 172 completed in 0.06min
# step 173 completed in 0.06min
# step 174 completed in 0.05min
# step 175 completed in 0.06min
# step 176 completed in 0.06min
# step 177 completed in 0.06min
# step 178 completed in 0.06min
# step 179 completed in 0.06min
# step 180 completed in 0.06min
# step 181 completed in 0.06min
# step 182 completed in 0.06min
# step 183 completed in 0.06min
# step 184 completed in 0.05min
# step 185 completed in 0.06min
# step 186 completed in 0.06min
# step 187 completed in 0.06min
# step 188 completed in 0.06min
# step 189 completed in 0.06min
# step 190 completed in 0.06min
# step 191 completed in 0.06min
# step 192 completed in 0.06min
# step 193 completed in 0.06min
# step 194 completed in 0.06min
# step 195 completed in 0.06min
# step 196 completed in 0.06min
# step 197 completed in 0.06min
# step 198 completed in 0.06min
# step 199 completed in 0.06min
# step 200 completed in 0.06min
# step 201 completed in 0.06min
# step 202 completed in 0.06min
# step 203 completed in 0.06min
# step 204 completed in 0.06min
# step 205 completed in 0.06min
# step 206 completed in 0.06min
# step 207 completed in 0.06min
# step 208 completed in 0.05min
# step 209 completed in 0.06min
# step 210 completed in 0.05min
# step 211 completed in 0.06min
# step 212 completed in 0.06min
# step 213 completed in 0.06min
# step 214 completed in 0.06min
# step 215 completed in 0.06min
# step 216 completed in 0.06min
# step 217 completed in 0.06min
# step 218 completed in 0.06min
# step 219 completed in 0.06min
# step 220 completed in 0.05min
# step 221 completed in 0.05min
# step 222 completed in 0.06min
# step 223 completed in 0.06min
# step 224 completed in 0.06min
# step 225 completed in 0.06min
# step 226 completed in 0.05min
# step 227 completed in 0.06min
# step 228 completed in 0.06min
# step 229 completed in 0.06min
# step 230 completed in 0.05min
# step 231 completed in 0.06min
# step 232 completed in 0.06min
# step 233 completed in 0.06min
# step 234 completed in 0.06min
# step 235 completed in 0.06min
# step 236 completed in 0.06min
# step 237 completed in 0.06min
# step 238 completed in 0.06min
# step 239 completed in 0.06min
# step 240 completed in 0.06min
# step 241 completed in 0.06min
# step 242 completed in 0.06min
# step 243 completed in 0.06min
# step 244 completed in 0.06min
# step 245 completed in 0.06min
# step 246 completed in 0.06min
# step 247 completed in 0.06min
# step 248 completed in 0.06min
# step 249 completed in 0.05min
# step 250 completed in 0.06min
# step 251 completed in 0.06min
# step 252 completed in 0.06min
# step 253 completed in 0.06min
# step 254 completed in 0.06min
# step 255 completed in 0.06min
# step 256 completed in 0.06min
# step 257 completed in 0.06min
# step 258 completed in 0.06min
# step 259 completed in 0.06min
# step 260 completed in 0.06min
# step 261 completed in 0.06min
# step 262 completed in 0.06min
# step 263 completed in 0.05min
# step 264 completed in 0.06min
# step 265 completed in 0.06min
# step 266 completed in 0.06min
# step 267 completed in 0.06min
# step 268 completed in 0.06min
# step 269 completed in 0.06min
# step 270 completed in 0.06min
# step 271 completed in 0.06min
# step 272 completed in 0.05min
# step 273 completed in 0.06min
# step 274 completed in 0.05min
# step 275 completed in 0.06min
# step 276 completed in 0.06min
# step 277 completed in 0.06min
# step 278 completed in 0.06min
# step 279 completed in 0.06min
# step 280 completed in 0.06min
# step 281 completed in 0.06min
# step 282 completed in 0.05min
# step 283 completed in 0.06min
# step 284 completed in 0.06min
# step 285 completed in 0.06min
# step 286 completed in 0.05min
# step 287 completed in 0.05min
# step 288 completed in 0.06min
# step 289 completed in 0.06min
# step 290 completed in 0.06min
# step 291 completed in 0.06min
# step 292 completed in 0.06min
# step 293 completed in 0.05min
# step 294 completed in 0.06min
# step 295 completed in 0.05min
# step 296 completed in 0.05min
# step 297 completed in 0.06min
# step 298 completed in 0.06min
# step 299 completed in 0.06min
# step 300 completed in 0.05min
# step 301 completed in 0.05min
# step 302 completed in 0.06min
# step 303 completed in 0.06min
# step 304 completed in 0.06min
# step 305 completed in 0.05min
# step 306 completed in 0.06min
# step 307 completed in 0.06min
# step 308 completed in 0.06min
# step 309 completed in 0.05min
# step 310 completed in 0.06min
# step 311 completed in 0.06min
# step 312 completed in 0.06min
# step 313 completed in 0.05min
# step 314 completed in 0.05min
# step 315 completed in 0.06min
# step 316 completed in 0.06min
# step 317 completed in 0.06min
# step 318 completed in 0.06min
# step 319 completed in 0.06min
# step 320 completed in 0.06min
# step 321 completed in 0.06min
# step 322 completed in 0.06min
# step 323 completed in 0.06min
# step 324 completed in 0.06min
# step 325 completed in 0.06min
# step 326 completed in 0.06min
# step 327 completed in 0.06min
# step 328 completed in 0.06min
# step 329 completed in 0.06min
# step 330 completed in 0.06min
# step 331 completed in 0.05min
# step 332 completed in 0.05min
# step 333 completed in 0.06min
# step 334 completed in 0.05min
# step 335 completed in 0.05min
# step 336 completed in 0.06min
# step 337 completed in 0.05min
# step 338 completed in 0.06min
# step 339 completed in 0.06min
# step 340 completed in 0.05min
# step 341 completed in 0.05min
# step 342 completed in 0.05min
# step 343 completed in 0.06min
# step 344 completed in 0.06min
# step 345 completed in 0.05min
# step 346 completed in 0.06min
# step 347 completed in 0.05min
# step 348 completed in 0.05min
# step 349 completed in 0.05min
# step 350 completed in 0.06min
# step 351 completed in 0.06min
# step 352 completed in 0.06min
# step 353 completed in 0.05min
# step 354 completed in 0.05min
# step 355 completed in 0.05min
# step 356 completed in 0.06min
# step 357 completed in 0.06min
# step 358 completed in 0.06min
# step 359 completed in 0.06min
# step 360 completed in 0.06min
# step 361 completed in 0.06min
# step 362 completed in 0.06min
# step 363 completed in 0.06min
# step 364 completed in 0.06min
# step 365 completed in 0.06min
# step 366 completed in 0.06min
# step 367 completed in 0.06min
# step 368 completed in 0.06min
# step 369 completed in 0.06min
# step 370 completed in 0.06min
# step 371 completed in 0.06min
# step 372 completed in 0.06min
# step 373 completed in 0.06min
# step 374 completed in 0.06min
# step 375 completed in 0.06min
# step 376 completed in 0.06min
# step 377 completed in 0.06min
# step 378 completed in 0.06min
# step 379 completed in 0.06min
# step 380 completed in 0.06min
# step 381 completed in 0.06min
# step 382 completed in 0.06min
# step 383 completed in 0.06min
# step 384 completed in 0.06min
# step 385 completed in 0.06min
# step 386 completed in 0.06min
# step 387 completed in 0.05min
# step 388 completed in 0.06min
# step 389 completed in 0.06min
# step 390 completed in 0.06min
# step 391 completed in 0.06min
# step 392 completed in 0.06min
# step 393 completed in 0.06min
# step 394 completed in 0.06min
# step 395 completed in 0.06min
# step 396 completed in 0.06min
# step 397 completed in 0.06min
# step 398 completed in 0.06min
# step 399 completed in 0.06min
# step 400 completed in 0.06min
# step 401 completed in 0.06min
# step 402 completed in 0.06min
# step 403 completed in 0.06min
# step 404 completed in 0.06min
# step 405 completed in 0.06min
# step 406 completed in 0.06min
# step 407 completed in 0.06min
# step 408 completed in 0.06min
# step 409 completed in 0.06min
# step 410 completed in 0.06min
# step 411 completed in 0.06min
# step 412 completed in 0.06min
# step 413 completed in 0.06min
# step 414 completed in 0.06min
# step 415 completed in 0.06min
# step 416 completed in 0.06min
# step 417 completed in 0.06min
# step 418 completed in 0.06min
# step 419 completed in 0.06min
# step 420 completed in 0.06min
# step 421 completed in 0.06min
# step 422 completed in 0.06min
# step 423 completed in 0.06min
# step 424 completed in 0.06min
# step 425 completed in 0.06min
# step 426 completed in 0.06min
# step 427 completed in 0.05min
# step 428 completed in 0.06min
# step 429 completed in 0.05min
# step 430 completed in 0.06min
# step 431 completed in 0.06min
# step 432 completed in 0.06min
# step 433 completed in 0.06min
# step 434 completed in 0.06min
# step 435 completed in 0.06min
# step 436 completed in 0.06min
# step 437 completed in 0.06min
# step 438 completed in 0.06min
# step 439 completed in 0.06min
# step 440 completed in 0.06min
# step 441 completed in 0.06min
# step 442 completed in 0.06min
# step 443 completed in 0.06min
# step 444 completed in 0.06min
# step 445 completed in 0.06min
# step 446 completed in 0.06min
# step 447 completed in 0.06min
# step 448 completed in 0.06min
# step 449 completed in 0.06min
# step 450 completed in 0.06min
# step 451 completed in 0.06min
# step 452 completed in 0.06min
# step 453 completed in 0.05min
# step 454 completed in 0.05min
# step 455 completed in 0.06min
# step 456 completed in 0.06min
# step 457 completed in 0.05min
# step 458 completed in 0.06min
# step 459 completed in 0.06min
# step 460 completed in 0.06min
# step 461 completed in 0.06min
# step 462 completed in 0.06min
# step 463 completed in 0.06min
# step 464 completed in 0.06min
# step 465 completed in 0.05min
# step 466 completed in 0.06min
# step 467 completed in 0.06min
# step 468 completed in 0.06min
# step 469 completed in 0.05min
# step 470 completed in 0.06min
# step 471 completed in 0.06min
# step 472 completed in 0.06min
# step 473 completed in 0.06min
# step 474 completed in 0.06min
# step 475 completed in 0.05min
# step 476 completed in 0.06min
# step 477 completed in 0.06min
# step 478 completed in 0.05min
# step 479 completed in 0.05min
# step 480 completed in 0.06min
# step 481 completed in 0.06min
# step 482 completed in 0.05min
# step 483 completed in 0.05min
# step 484 completed in 0.05min
# step 485 completed in 0.05min
# step 486 completed in 0.06min
# step 487 completed in 0.06min
# step 488 completed in 0.05min
# step 489 completed in 0.06min
# step 490 completed in 0.05min
# step 491 completed in 0.06min
# step 492 completed in 0.06min
# step 493 completed in 0.06min
# step 494 completed in 0.05min
# step 495 completed in 0.05min
# step 496 completed in 0.06min
# step 497 completed in 0.06min
# step 498 completed in 0.06min
# step 499 completed in 0.06min
# step 500 completed in 0.06min
# step 501 completed in 0.06min
# step 502 completed in 0.05min
# step 503 completed in 0.06min
# step 504 completed in 0.06min
# step 505 completed in 0.06min
# step 506 completed in 0.05min
# step 507 completed in 0.06min
# step 508 completed in 0.06min
# step 509 completed in 0.06min
# step 510 completed in 0.05min
# step 511 completed in 0.06min
# step 512 completed in 0.06min
# step 513 completed in 0.06min
# step 514 completed in 0.05min
# step 515 completed in 0.06min
# step 516 completed in 0.05min
# step 517 completed in 0.06min
# step 518 completed in 0.06min
# step 519 completed in 0.06min
# step 520 completed in 0.06min
# step 521 completed in 0.06min
# step 522 completed in 0.06min
# step 523 completed in 0.06min
# step 524 completed in 0.06min
# step 525 completed in 0.06min
# step 526 completed in 0.05min
# step 527 completed in 0.05min
# step 528 completed in 0.05min
# step 529 completed in 0.05min
# step 530 completed in 0.06min
# step 531 completed in 0.06min
# step 532 completed in 0.06min
# step 533 completed in 0.06min
# step 534 completed in 0.06min
# step 535 completed in 0.06min
# step 536 completed in 0.06min
# step 537 completed in 0.06min
# step 538 completed in 0.06min
# step 539 completed in 0.06min
# step 540 completed in 0.06min
# step 541 completed in 0.06min
# step 542 completed in 0.06min
# step 543 completed in 0.05min
# step 544 completed in 0.06min
# step 545 completed in 0.06min
# step 546 completed in 0.06min
# step 547 completed in 0.06min
# step 548 completed in 0.06min
# step 549 completed in 0.06min
# step 550 completed in 0.06min
# step 551 completed in 0.05min
# step 552 completed in 0.05min
# step 553 completed in 0.06min
# step 554 completed in 0.06min
# step 555 completed in 0.06min
# step 556 completed in 0.06min
# step 557 completed in 0.05min
# step 558 completed in 0.06min
# step 559 completed in 0.05min
# step 560 completed in 0.06min
# step 561 completed in 0.06min
# step 562 completed in 0.06min
# step 563 completed in 0.06min
# step 564 completed in 0.06min
# step 565 completed in 0.06min
# step 566 completed in 0.06min
# step 567 completed in 0.06min
# step 568 completed in 0.06min
# step 569 completed in 0.06min
# step 570 completed in 0.06min
# step 571 completed in 0.06min
# step 572 completed in 0.06min
# step 573 completed in 0.06min
# step 574 completed in 0.06min
# step 575 completed in 0.06min
# step 576 completed in 0.05min
# step 577 completed in 0.05min
# step 578 completed in 0.06min
# step 579 completed in 0.06min
# step 580 completed in 0.06min
# step 581 completed in 0.06min
# step 582 completed in 0.06min
# step 583 completed in 0.06min
# step 584 completed in 0.05min
# step 585 completed in 0.05min
# step 586 completed in 0.06min
# step 587 completed in 0.06min
# step 588 completed in 0.06min
# step 589 completed in 0.06min
# step 590 completed in 0.06min
# step 591 completed in 0.06min
# step 592 completed in 0.06min
# step 593 completed in 0.06min
# step 594 completed in 0.05min
# step 595 completed in 0.06min
# step 596 completed in 0.06min
# step 597 completed in 0.06min
# step 598 completed in 0.06min
# step 599 completed in 0.06min
# step 600 completed in 0.06min
# step 601 completed in 0.06min
# step 602 completed in 0.06min
# step 603 completed in 0.06min
# step 604 completed in 0.06min
# step 605 completed in 0.06min
# step 606 completed in 0.06min
# step 607 completed in 0.06min
# step 608 completed in 0.06min
# step 609 completed in 0.06min
# step 610 completed in 0.05min
# step 611 completed in 0.06min
# step 612 completed in 0.06min
# step 613 completed in 0.06min
# step 614 completed in 0.06min
# step 615 completed in 0.05min
# step 616 completed in 0.06min
# step 617 completed in 0.06min
# step 618 completed in 0.06min
# step 619 completed in 0.06min
# step 620 completed in 0.06min
# step 621 completed in 0.06min
# step 622 completed in 0.06min
# step 623 completed in 0.06min
# step 624 completed in 0.06min
# simulation completed in 34.83min

# %%
fig,ax = plt.subplots()
ax.imshow(slices_soln)
ax.set_aspect(0.005)

# %%
fig,ax = plt.subplots()
cmap = ax.contourf(soln/I2max,extent=[1e3*b_steps[0], 1e3*b_steps[-1], phi_steps[0], phi_steps[-1]]) # left right bottom top
fig.colorbar(cmap)
# ax.set_aspect(.01)
ax.set_xlabel('Iris radius b [mm]')
ax.set_ylabel('Relative mask phase [deg]')
# savefigure(f'min_ta_{int(100*ta)}_phi_steps_{int(phi_steps[0])}_{int(phi_steps[-1])}_{numstepsy}pts_b_steps_{int(b_steps[0]*1e6)}_{int(b_steps[-1]*1e6)}um_{numstepsx}pts.svg')
# savefigure(f'min_T_aper_{int(100*T_aper)}_phi_steps_{int(phi_steps[0])}_{int(phi_steps[-1])}_{numstepsy}pts_b_steps_{int(b_steps[0]*1e6)}_{int(b_steps[-1]*1e6)}um_{numstepsx}pts.png')
# Out:
# Text(0, 0.5, 'Relative mask phase [deg]')

# %%
(soln/I2max)[-1,-1]
# Out:
# 1.772957407993106

# %%
fig,ax = plt.subplots()
cmap = ax.imshow(soln/I2max-amin(soln/I2max),origin='lower',extent=[1e3*b_steps[0], 1e3*b_steps[-1], phi_steps[0], phi_steps[-1]]) # left right bottom top
fig.colorbar(cmap)
ax.set_aspect(1/90)
# soln_to_csv(f'min_ta_{int(100*ta)}_phi_steps_{int(phi_steps[0])}_{int(phi_steps[-1])}_{numstepsy}pts_b_steps_{int(b_steps[0]*1e6)}_{int(b_steps[-1]*1e6)}um_{numstepsx}pts.csv',soln/I2max-amin(soln/I2max),labels=None,
#             metastr='params in filename. i(rows) is phi steps, j(cols) is b steps. data[0,0] or phi=0,b=2.4e-3 correspond to the ideal 4f filtering design')
# savefigure(f'min_ta_{int(100*ta)}_phi_steps_{int(phi_steps[0])}_{int(phi_steps[-1])}_{numstepsy}pts_b_steps_{int(b_steps[0]*1e6)}_{int(b_steps[-1]*1e6)}um_{numstepsx}pts.svg')
# Out:
# wrote data to min_ta_28_phi_steps_0_180_25pts_b_steps_600_2500um_25pts.csv
# saved file to ..\images\min_ta_28_phi_steps_0_180_25pts_b_steps_600_2500um_25pts.svg

# %%
amin(soln/I2max)
# Out:
# 6.763373207462997e-07

# %%
b_steps[0]
# Out:
# 0.0006

# %%
b/(f1/(a*k))/3.8317
# Out:
# 1.0

# %%
plt.plot((soln/I2max)[0,:],label='phi=0')
plt.plot((soln/I2max)[-1,:],label='phi=180')
plt.ylim((0,1))
plt.legend()

# %%
soln.shape
# Out:
# (25, 25)

# %%
soln_to_csv?

# %%
plt.plot(range(numstepsx),soln[-1,:]/I2max)
plt.ylim((0.1,0.7))
# Out:
# (0.1, 0.7)

# %%
# input mask
pts = 1001
phi_std=None # [rad]
pos_std=None

phi = 140
T_aper = 0.49 # a far from optimal reflectivity value
r_aper = sqrt(1-T_aper) # aperture reflectivity
t_plate = 1 # plate transmissivity
mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
complement, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=0, plate=1)
spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
spot_phases *= exp(-1j*phi*pi/180)
phase_mask = spot_phases + complement

# range of spot phases wrt to background
numsteps = 5
b_steps = linspace(1e-3,1.3e-3,numsteps)
I2max = 1

z2 = f2 # output plane

xslice = 453 # x coordinate of the slice
slices_soln = empty((pts,numsteps),dtype=float) 

for i,bs in enumerate(b_steps):

    # calculate the input field
    print(f'b={bs*1e3}mm')
    mask, x0pts, w = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=sqrt(T_aper), plate=t_plate)
    
#     add phases to input field 
#     spot_phases, _, _ = spot_mask(xnum1, ynum1, a, dx, dy, pts, phi_std=phi_std, pos_std=pos_std, aperture=1, plate=0)
#     spot_phases *= exp(-1j*phi*pi/180)
#     phase_mask = spot_phases + complement

#     finally, apply the phases to the transmission mask
    field0 = mask*phase_mask

    # FOURIER PLANE FIELD -- propogate the field and apply a filter in the Fourier plane
    padding= int(3*pts/2) 
    rr0 = sqrt(x0pts**2 + x0pts.reshape(-1,1)**2)
    field1,x1pts = lens_xform(f1,field0,bs,f1,k,x0pts,rr0,padding,masked=False,padval=1,
                              logging=False)

    # OUTPUT FIELD -- propagate field in Fourier plane to z2 behind lens f2 
    rr1 = sqrt(x1pts**2 + x1pts.reshape(-1,1)**2)
    field2,x2pts = lens_xform(z2,field1,bs,f2,k,x1pts,rr1,padding,masked=True,
                              logging=False)
    
    if bs == b:
        I2max = max(abs(field2[:,xslice])**2)
        print("obtained normalization factor")
    
    slices_soln[:,i] = abs(field2[:,xslice])**2
    print(f"step {i} completed")
    
I2max = max(abs(field2[:,xslice])**2)
for i in range(numsteps):
    slices_soln[:,i] /= I2max
# Out:
# b=1.0mm
# step 0 completed
# b=1.075mm
# step 1 completed
# b=1.15mm
# step 2 completed
# b=1.2249999999999999mm
# step 3 completed
# b=1.3mm
# step 4 completed

# %%
savefig=False
fig,ax = plt.subplots(dpi=100)
for i in [0,-1]:
    ax.plot(range(pts),slices_soln[:,i],label=f'b={b_steps[i]*1e3:0.2f}')
ax.set_title(f"Trap Intensity Dependence on \nIris Radius. T_aper={T_aper}, spot phase={phi}deg",fontsize=fontsize)
ax.set_xlabel("x [Arb.]",fontsize=fontsize)
ax.set_ylabel("Intensity",fontsize=fontsize)
# ax.set_ylim((0,0.025))
# ax.set_xlim((440,470))
ax.legend()
if savefig:
    fname = f"plot_trap_profile_spot_t_plate_{int(100*t_plate)}_phi_{phi}_T_aper_{int(100*T_aper)}_b_steps_{int(b_steps[0]*1e6)}_{int(b_steps[-1])}um_{numsteps}pts.png"
    savefigure(fname)

# %%
0.001/b
# Out:
# 0.40740136959331485
